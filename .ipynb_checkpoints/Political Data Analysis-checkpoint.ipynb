# %%
import pandas as pd

pol_data = pd.read_csv("political_data/1976-2018-senate.csv", encoding='utf-8')
pol_data
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Arizona       AZ           4         86        61
# 1     1976        Arizona       AZ           4         86        61
# 2     1976        Arizona       AZ           4         86        61
# 3     1976        Arizona       AZ           4         86        61
# 4     1976        Arizona       AZ           4         86        61
# 5     1976     California       CA           6         93        71
# 6     1976     California       CA           6         93        71
# 7     1976     California       CA           6         93        71
# 8     1976     California       CA           6         93        71
# 9     1976     California       CA           6         93        71
# 10    1976    Connecticut       CT           9         16         1
# 11    1976    Connecticut       CT           9         16         1
# 12    1976    Connecticut       CT           9         16         1
# ...

# %%
tendata = pol_data.year.contains("2010")
tendata
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-300daa211c45> in <module>
# ----> 1 tendata = pol_data.year.str.contains("2010")
#       2 tendata
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...
