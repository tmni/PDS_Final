# %%
import pandas as pd

pol_data = pd.read_csv("political_data/1976-2016-president.csv", encoding='utf-8')
pol_data
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Alabama       AL           1         63        41
# 1     1976        Alabama       AL           1         63        41
# 2     1976        Alabama       AL           1         63        41
# 3     1976        Alabama       AL           1         63        41
# 4     1976        Alabama       AL           1         63        41
# 5     1976        Alabama       AL           1         63        41
# 6     1976        Alabama       AL           1         63        41
# 7     1976         Alaska       AK           2         94        81
# 8     1976         Alaska       AK           2         94        81
# 9     1976         Alaska       AK           2         94        81
# 10    1976         Alaska       AK           2         94        81
# 11    1976        Arizona       AZ           4         86        61
# 12    1976        Arizona       AZ           4         86        61
# ...

# %%
tendata = pol_data[pol_data["year"] == 2012]
grouped_by_state= tendata.groupby("state").nth(0) #returns highest candidate votes for each state
# df = tendata.groupby('state')['candidatevotes'].apply(lambda x: x.value_counts().index[0]).reset_index()
sandp = df["state", "party"]
sandp
# Out:
#                       year state_po  state_fips  state_cen  state_ic  \
# state
# Alabama               2012       AL           1         63        41
# Alaska                2012       AK           2         94        81
# Arizona               2012       AZ           4         86        61
# Arkansas              2012       AR           5         71        42
# California            2012       CA           6         93        71
# Colorado              2012       CO           8         84        62
# Connecticut           2012       CT           9         16         1
# Delaware              2012       DE          10         51        11
# District of Columbia  2012       DC          11         53        55
# Florida               2012       FL          12         59        43
# Georgia               2012       GA          13         58        44
# Hawaii                2012       HI          15         95        82
# ...

# %%
# sgroup = grouped_by_state.apply(lambda new: new.sort_values(by=['candidatevotes'], ascending=False))
# wow = sgroup.first().reset_index()
# wow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8d71e5340712> in <module>
#       1 sgroup = grouped_by_state.apply(lambda new: new.sort_values(by=['candidatevotes'], ascending=False))
# ----> 2 wow = sgroup.first().reset_index()
#       3 wow
#
# TypeError: first() missing 1 required positional argument: 'offset'
