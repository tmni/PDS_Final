# %%
import pandas as pd
data = pd.read_csv("income_data_state.csv", encoding='utf-8', header = 3)
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
