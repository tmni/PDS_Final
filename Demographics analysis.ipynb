# %%
import pandas as pd

pop_data = pd.read_csv("Population data/pop_density.csv", header=3)
# pol_data = pd.read_csv("political_data/1976-2018-senate.csv", encoding='utf-8')

race_data_1 = pd.read_csv("Population data/stco-mr2010_al_mo.csv")
race_data_2 = pd.read_csv("Population data/stco-mr2010_mt_wy.csv", encoding='latin-1')

race_data = pd.concat([race_data_1, race_data_2])
# race_data
# Out:
#         SUMLEV  STATE  COUNTY   STNAME         CTYNAME  SEX  ORIGIN  AGEGRP  \
# 0           50      1       1  Alabama  Autauga County    1       1       1
# 1           50      1       1  Alabama  Autauga County    1       1       1
# 2           50      1       1  Alabama  Autauga County    1       1       1
# 3           50      1       1  Alabama  Autauga County    1       1       1
# 4           50      1       1  Alabama  Autauga County    1       1       1
# ...        ...    ...     ...      ...             ...  ...     ...     ...
# 620182      50     56      45  Wyoming   Weston County    2       2      12
# 620183      50     56      45  Wyoming   Weston County    2       2      13
# 620184      50     56      45  Wyoming   Weston County    2       2      15
# 620185      50     56      45  Wyoming   Weston County    2       2      16
# 620186      50     56      45  Wyoming   Weston County    2       2      18
#
#         IMPRACE  RESPOP
# 0             1    1337
# 1             2     356
# 2             3       2
# 3             4      13
# 4             6      33
# ...         ...     ...
# 620182        1       2
# 620183        1       2
# 620184        1       1
# 620185        1       1
# 620186        1       2
#
# [1260772 rows x 10 columns]

# %%
# Now, grouping these by city
# Out:
#     SUMLEV  STATE  COUNTY   STNAME         CTYNAME  SEX  ORIGIN  AGEGRP  \
# 0       50      1       1  Alabama  Autauga County    1       1       1
# 1       50      1       1  Alabama  Autauga County    1       1       1
# 2       50      1       1  Alabama  Autauga County    1       1       1
# 3       50      1       1  Alabama  Autauga County    1       1       1
# 4       50      1       1  Alabama  Autauga County    1       1       1
# 5       50      1       1  Alabama  Autauga County    1       1       1
# 6       50      1       1  Alabama  Autauga County    1       1       1
# 7       50      1       1  Alabama  Autauga County    1       1       1
# 8       50      1       1  Alabama  Autauga County    1       1       1
# 9       50      1       1  Alabama  Autauga County    1       1       1
# 10      50      1       1  Alabama  Autauga County    1       1       1
# 11      50      1       1  Alabama  Autauga County    1       1       1
# 12      50      1       1  Alabama  Autauga County    1       1       1
# 13      50      1       1  Alabama  Autauga County    1       1       2
# 14      50      1       1  Alabama  Autauga County    1       1       2
# 15      50      1       1  Alabama  Autauga County    1       1       2
# 16      50      1       1  Alabama  Autauga County    1       1       2
# 17      50      1       1  Alabama  Autauga County    1       1       2
# 18      50      1       1  Alabama  Autauga County    1       1       2
# 19      50      1       1  Alabama  Autauga County    1       1       2
#
#     IMPRACE  RESPOP
# 0         1    1337
# 1         2     356
# 2         3       2
# 3         4      13
# 4         6      33
# 5         7      11
# 6         8      17
# 7        10       4
# 8        11       1
# 9        16       1
# 10       17       1
# 11       19       1
# 12       21       1
# 13        1    1460
# 14        2     398
# 15        3      12
# 16        4      17
# 17        6      21
# 18        7       9
# 19        8      10
